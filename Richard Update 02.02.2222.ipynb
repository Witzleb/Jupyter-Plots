# %% [markdown]
# In der Abbildung weiter unten sieht man die Ergebnisse für den PI mit den Peaks bei der fold bifurcation und der subcritical bifurcation, mit der Idee, dass diese wenigen hohen Peaks die Correlation zwischen WTA und PI zerstören.
# Kritische Werte sind für die fold bifurcation also J = 13; 13,2 und für die subcrit HB J = 14,8; 15

# %% [markdown]
# ![Master_Abb_17.01.22.png](attachment:Master_Abb_17.01.22.png)

# %% [markdown]
# Der PI errechnet sich ja aus den ersten beiden Peaks der Impulsantwort von Z. Eine Idee war, dass die hohen Werte für den PI aus einem Phasenübergang für Z resultieren. Das passiert bei der fold bifurcation simultan mit dem Phasenübergang von niedrigem r zu hohem r.
# Siehe Abbildung: In der Mitte wird das J des hohen PI peaks abgebildet.
#
# ![Z_peak_fold-2.png](attachment:Z_peak_fold-2.png)

# %% [markdown]
# Bei der subkritischen HB passiert das Ganze ohne Niveauänderung in Z. Damit ist die Idee wohl hinfällig.
#
# ![Z_peak_subcrit-2.png](attachment:Z_peak_subcrit-2.png)

# %% [markdown]
# Ansonsten sieht die Correlation zwischen RC und MF sehr gut aus.
#
# ![correlation_yeah.png](attachment:correlation_yeah.png)
