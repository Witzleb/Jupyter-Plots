# %% [markdown]
# Hey Richard,
# ich hoffe du bist gut in Amerika angenommen und lebst dich gut ein.
# Danke für deine Hilfestellungen in der letzten Mail. Es ist mir wieder möglich, Remote Server Simulationen durchzuführen.
#
# Ich habe noch einiges herumprobiert mit den Correlations zwischen dem PI und dem Wta Score bei verschiedenen Parametern des Netzwerkes und der Simulation.
# Die Ergebnisse, die wir dafür bei den ersten Probe-Simulationen im Dezember bekommen haben, waren ziemlich gut. Daher habe versucht diese Parameter wiederzufinden, oder, zu schauen, wann die Correlation zwischen PI & WTA gut ist.
# Ich weiß nicht, wieso der WTA Score bei den Messwerten im November so niedrig war, also bis unter 0.3 gefallen ist. Ich habe mit verschiedenen Input-Stärken, Input-Channels, Neuronenanzahlen und Simulationszeiten herumgespielt. Und bekomme jetzt auch ähnliche Ergebnisse mit immer noch höheren WTA Werten.
# ![Master_Abb_17.01.22.png](attachment:Master_Abb_17.01.22.png)

# %% [markdown]
# Bei der subkritischen Hopf Bifurkation gibt es einen Peak im PI während der Bifurkation. In den Simulationen mit nur 50 Werten für J war die Auflösung niedrig genug, so dass dieser Peak nicht aufgenommen wurde. Zumindest ist das meine Interpretation. Für 100 J’s ist er aber da und verzerrt die correlation ziemlich stark. . Für die fold bifurcation sieht es sehr ähnlich aus.
# ![sub_hb_50_100.png](attachment:sub_hb_50_100.png)

# %% [markdown]
# Desweiteren habe ich den external Input der zur Bestimmung des PI in die Meanfield Simulation eingespeist wird, auch in das QIF Netzwerk integriert, und das sieht ganz gut aus. Bei der fold bifurcation wird das Netzwerk sogar vom niedrigen Niveau Außer für die superkritische Hopf Bifurkation, da finde ich seit den ersten Simulationen im Dezember keine großen Oszillationen mehr, und mache gerade Versuche mit weniger Neuronen im Reservoir.
# ![corr_QIF_MF_2022.png](attachment:corr_QIF_MF_2022.png)

# %% [markdown]
# Als Reservoir Gleichungen habe ich jetzt die Summenformeln aus den Skripten mit übernommen. Wenn du andere Gleichungen meinst, dann verstehe ich dich nicht und wir reden aneinander vorbei.
#
# zitat:
#
# where the external input has a heterogeneous background current 𝜂𝑖 as well as a common time-varying compnent 𝐼(𝑡), and the recurrent input is the synaptic weight 𝐽 time the mean synaptic activation 𝑠
#
# which is:
#
# $s = \frac{1}{N} \sum^{N}_{j=1} \sum_{k/t^{k}_{j}<t} \int^{t}_{-\infty}{a_{\tau}(t-t^{'})\delta(t^{'}-t^{k}_{j})dt^{'}} $
#
# with neuron number N. Here, $t_{j}^{k}$ is the time of the k'th spike of the j'th neuron, $\delta$ is the Dirac delta function, and $a_{\tau}$ is the normalized synaptic activation caused by a single presynaptic spike with time scale τ, which is in our cause exponential;  e.g., $a_{\tau}(t) = e^{-t/\tau}/\tau$.
#
# Zitat Ende.
